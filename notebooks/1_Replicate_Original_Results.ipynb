# %%
# 导入必要的库
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# 设置绘图风格
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

print("环境设置完成！")

# %% [markdown]
# ## 步骤 1: 加载原始代码
#
# 将导师的原始代码放在 `original_code/` 目录中，然后在这里导入和运行。

# %%
# 添加原始代码路径
import sys
sys.path.append('../original_code')

# 导入原始代码模块（根据实际情况修改）
# from original_module import *

print("原始代码模块导入完成")

# %% [markdown]
# ## 步骤 2: 运行实验
#
# 执行原始代码的主要实验。

# %%
# 运行原始实验
# 根据实际情况修改

# 示例:
# results = run_original_experiment()
# print(f"实验完成，获得 {len(results)} 个结果")

# %% [markdown]
# ## 步骤 3: 可视化结果
#
# 绘制关键指标的图表。

# %%
# 可视化结果
# 示例:
# plt.figure(figsize=(12, 6))
# plt.plot(results['x'], results['y'], 'o-')
# plt.xlabel('X Label')
# plt.ylabel('Y Label')
# plt.title('Original Results')
# plt.grid(True, alpha=0.3)
# plt.show()

print("可视化完成")

# %% [markdown]
# ## 步骤 4: 保存结果
#
# 将结果保存到 `results/` 目录。

# %%
# 保存结果
output_dir = Path('../results/data')
output_dir.mkdir(parents=True, exist_ok=True)

# 示例:
# df = pd.DataFrame(results)
# df.to_csv(output_dir / 'original_results.csv', index=False)

print("结果已保存")

# %% [markdown]
# ## 总结
#
# 记录关键发现和观察结果。
#
# ### 主要发现:
# - [在这里记录你的发现]
#
# ### 与论文的对比:
# - [对比论文中的结果]
